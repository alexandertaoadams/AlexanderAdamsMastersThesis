# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandertaoadams/AlexanderAdamsMastersThesis/blob/main/NB_Chinatown_Sparse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Time Series Classification: Chinatown
#
# **URL to original dataset:**
# https://www.timeseriesclassification.com/description.php?Dataset=Chinatown
#
#
# This notebook trains a **sparse variational Gaussian Process** on the Chinatown dataset.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install gpjax
# !pip install sktime
# Out:
# Requirement already satisfied: gpjax in /usr/local/lib/python3.12/dist-packages (0.13.4)
# Requirement already satisfied: beartype>0.16.1 in /usr/local/lib/python3.12/dist-packages (from gpjax) (0.22.6)
# Requirement already satisfied: flax>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gpjax) (0.12.1)
# Requirement already satisfied: jax>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from gpjax) (0.8.1)
# Requirement already satisfied: jaxlib>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from gpjax) (0.8.1)
# Requirement already satisfied: jaxtyping>0.2.10 in /usr/local/lib/python3.12/dist-packages (from gpjax) (0.3.3)
# Requirement already satisfied: numpy>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from gpjax) (2.0.2)
# Requirement already satisfied: numpyro in /usr/local/lib/python3.12/dist-packages (from gpjax) (0.19.0)
# Requirement already satisfied: optax>0.2.1 in /usr/local/lib/python3.12/dist-packages (from gpjax) (0.2.6)
# Requirement already satisfied: tqdm>4.66.2 in /usr/local/lib/python3.12/dist-packages (from gpjax) (4.67.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from flax>=0.12.0->gpjax) (1.1.2)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.12/dist-packages (from flax>=0.12.0->gpjax) (0.11.28)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.12/dist-packages (from flax>=0.12.0->gpjax) (0.1.79)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.12/dist-packages (from flax>=0.12.0->gpjax) (14.2.0)
# Requirement already satisfied: typing_extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from flax>=0.12.0->gpjax) (4.15.0)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.12/dist-packages (from flax>=0.12.0->gpjax) (6.0.3)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from flax>=0.12.0->gpjax) (0.1.10)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax>=0.5.0->gpjax) (0.5.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax>=0.5.0->gpjax) (3.4.0)
# Requirement already satisfied: scipy>=1.13 in /usr/local/lib/python3.12/dist-packages (from jax>=0.5.0->gpjax) (1.16.3)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from jaxtyping>0.2.10->gpjax) (0.1.7)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from optax>0.2.1->gpjax) (1.4.0)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.12/dist-packages (from optax>0.2.1->gpjax) (0.1.90)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.12/dist-packages (from numpyro->gpjax) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from chex>=0.1.87->optax>0.2.1->gpjax) (75.2.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chex>=0.1.87->optax>0.2.1->gpjax) (1.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1->flax>=0.12.0->gpjax) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1->flax>=0.12.0->gpjax) (2.19.2)
# Requirement already satisfied: etils[epath,epy] in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.12.0->gpjax) (1.13.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.12.0->gpjax) (1.6.0)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.12.0->gpjax) (25.1.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.12.0->gpjax) (6.33.1)
# Requirement already satisfied: humanize in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.12.0->gpjax) (4.14.0)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.12.0->gpjax) (3.20.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.12.0->gpjax) (5.9.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.12.0->gpjax) (0.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.12.0->gpjax) (2025.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.12.0->gpjax) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.12.0->gpjax) (3.23.0)
# Requirement already satisfied: sktime in /usr/local/lib/python3.12/dist-packages (0.40.1)
# Requirement already satisfied: joblib<1.6,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from sktime) (1.5.2)
# Requirement already satisfied: numpy<2.4,>=1.21 in /usr/local/lib/python3.12/dist-packages (from sktime) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from sktime) (25.0)
# Requirement already satisfied: pandas<2.4.0,>=1.1 in /usr/local/lib/python3.12/dist-packages (from sktime) (2.2.2)
# Requirement already satisfied: scikit-base<0.14.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from sktime) (0.13.0)
# Requirement already satisfied: scikit-learn<1.8.0,>=0.24 in /usr/local/lib/python3.12/dist-packages (from sktime) (1.6.1)
# Requirement already satisfied: scipy<2.0.0,>=1.2 in /usr/local/lib/python3.12/dist-packages (from sktime) (1.16.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<2.4.0,>=1.1->sktime) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<2.4.0,>=1.1->sktime) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<2.4.0,>=1.1->sktime) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<1.8.0,>=0.24->sktime) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<2.4.0,>=1.1->sktime) (1.17.0)

# %%
# jax libraries
import numpy as np
import jax
import jax.numpy as jnp

# gpjax libraries
import gpjax as gpx

# core libraries
from flax import nnx
import optax as ox

# data manipulation and visualisation libraries
import pandas as pd
from sktime.datasets import load_from_tsfile
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# !git clone https://github.com/alexandertaoadams/AlexanderAdamsMastersThesis.git

import sys
sys.path.insert(0, '/content/AlexanderAdamsMastersThesis')
import AlexanderAdamsMastersThesis.src as src

from src.kernels import SignatureKernel
from src.inducing_variables import initial_inducing_variables
from src.utils import display_parameters, display_results, normalise

from src.models import CollapsedBernoulliVariationalGaussian
from src.objectives import collapsed_elbo_bernoulli
# Out:
# fatal: destination path 'AlexanderAdamsMastersThesis' already exists and is not an empty directory.

# %% [markdown]
# ### **Data Loading and Preprocessing**

# %%
file_path_train = "/content/drive/MyDrive/DATA_Chinatown/Chinatown_TRAIN.ts"
file_path_test = "/content/drive/MyDrive/DATA_Chinatown/Chinatown_TEST.ts"

train_data, train_labels = load_from_tsfile(file_path_train)
test_data, test_labels = load_from_tsfile(file_path_test)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3186760896.py in <cell line: 0>()
#       2 file_path_test = "/content/drive/MyDrive/DATA_Chinatown/Chinatown_TEST.ts"
#       3
# ----> 4 train_data, train_labels = load_from_tsfile(file_path_train)
#       5 test_data, test_labels = load_from_tsfile(file_path_test)
#
# /usr/local/lib/python3.12/dist-packages/sktime/datasets/_readers_writers/ts.py in load_from_tsfile(full_file_path_and_name, replace_missing_vals_with, return_y, return_data_type, encoding, y_dtype)
#     691
#     692     # Initialize flags and variables used when parsing the file
# --> 693     X, y = load_from_tsfile_to_dataframe(
#     694         full_file_path_and_name=full_file_path_and_name,
#     695         return_separate_X_and_y=True,
#
# /usr/local/lib/python3.12/dist-packages/sktime/datasets/_readers_writers/ts.py in load_from_tsfile_to_dataframe(full_file_path_and_name, return_separate_X_and_y, replace_missing_vals_with, encoding, y_dtype)
#      85
#      86     # Parse the file
# ---> 87     with open(full_file_path_and_name, encoding=encoding) as file:
#      88         for line in file:
#      89             # Strip white space from start/end of line and change to
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/DATA_Chinatown/Chinatown_TRAIN.ts'

# %%
train_data_2 = jnp.array((np.stack([np.stack(row) for row in train_data.to_numpy()])))
train_labels_2 = jnp.array([int(i)-1 for i in train_labels])
xtrain, train_mean, train_std = normalise(train_data_2)
ytrain = train_labels_2
print(xtrain.shape)
print(ytrain.shape)
print(ytrain)

# %%
test_data_2 = jnp.array((np.stack([np.stack(row) for row in test_data.to_numpy()])))
test_labels_2 = jnp.array([int(i)-1 for i in test_labels])
xtest = (test_data_2 - train_mean) / (train_std)
ytest = test_labels_2
print(xtest.shape)
print(ytest.shape)
print(ytest)

# %% [markdown]
# ### **Model Training**

# %%
# Initialising model
q_kernel = SignatureKernel(xtrain.shape[1], xtrain.shape[2], 4)
q_mean_function = gpx.mean_functions.Constant(constant=jnp.array([0.5]))
q_prior = gpx.gps.Prior(mean_function=q_mean_function, kernel=q_kernel)
q_likelihood = gpx.likelihoods.Bernoulli(xtrain.shape[0])
q_posterior = q_likelihood * q_prior

# Create dataset, initialise inducing variables
D = gpx.dataset.Dataset(jnp.reshape(xtrain, (xtrain.shape[0], -1)), jnp.expand_dims(ytrain, axis=1))
Z = initial_inducing_variables(xtrain, ytrain, 8)

# Model
q_collapsed = CollapsedBernoulliVariationalGaussian(
    posterior=q_posterior,
    inducing_inputs=Z
)

# %%
# Training
collapsed_optimised_model, history = gpx.fit(
    model=q_collapsed,
    objective= lambda model, data: -collapsed_elbo_bernoulli(model, data),
    train_data=D,
    optim=ox.adam(learning_rate=1e-4),
    trainable=gpx.parameters.Parameter,
    num_iters=2000,
    batch_size=20,
    verbose=True
)

# %%
# Plot training process
sns.set(style="whitegrid", context="talk")
plt.figure(figsize=(8, 5))
plt.plot(history, color="black", linewidth=0.5, label="Training ELBO")
plt.xlabel("Iteration", fontsize=12)
plt.ylabel("−ELBO", fontsize=12)
plt.tick_params(axis='both', which='major', labelsize=10)
plt.tight_layout()
plt.show()

# %%
# Display model hyperparameters
params = display_parameters(collapsed_optimised_model)
params

# %% [markdown]
# ### **Model Evaluation**

# %%
# Get predicted means
latent_dist = collapsed_optimised_model.predict(xtest, D)
predicted_dist = collapsed_optimised_model.posterior.likelihood(latent_dist)
predicted_mean_collapsed = predicted_dist.mean

# Get predicted class labels (round to nearest int)
predicted_labels_collapsed = jnp.round(predicted_mean_collapsed)

# print("Predicted means:", predicted_mean_collapsed)
# print("Predicted labels:", predicted_labels_collapsed)
# print("True labels:", ytest)

# %%
# Display results
results = display_results(predicted_labels_collapsed, ytest)
results
